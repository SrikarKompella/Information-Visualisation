# %%
import pandas as pd

# %%
aiddata = pd.read_csv("/Users/Bayernlad/Downloads/aiddata-countries-only.csv")

# %%
pd.read_csv("/Users/Bayernlad/Downloads/aiddata-countries-only.csv")
# Out:
#        Unnamed: 0    aiddata_id  aiddata_2_id  year            donor  \
# 0               1  2.414478e+06           NaN  1977     Saudi Arabia
# 1               2  2.414509e+06           NaN  1977     Saudi Arabia
# 2               3  2.414635e+06           NaN  1983     Saudi Arabia
# 3               4  2.414665e+06           NaN  1984     Saudi Arabia
# 4               5  2.414667e+06           NaN  1984     Saudi Arabia
# 5               6  2.414684e+06           NaN  1985     Saudi Arabia
# 6               7  2.414760e+06           NaN  1987     Saudi Arabia
# 7               8  2.414840e+06           NaN  1993           Kuwait
# 8               9  2.415076e+06           NaN  1996           Kuwait
# 9              10  2.415206e+06           NaN  1998           Kuwait
# 10             11  2.426999e+06           NaN  1978           Kuwait
# 11             12  2.427052e+06           NaN  1976           Kuwait
# 12             13  2.427058e+06           NaN  1976           Kuwait
# ...

# %%
purpose = aiddata.groupby(["coalesced_purpose_name","coalesced_purpose_code"])["commitment_amount_usd_constant"].sum()
df = pd.DataFrame(purpose)

# %%
df = df.sort_values(['commitment_amount_usd_constant'], ascending=False)
df.head(5)
# Out:
#                                                                commitment_amount_usd_constant
# coalesced_purpose_name                 coalesced_purpose_code
# Air transport                          21050                                     3.981248e+10
# Rail transport                         21030                                     2.049887e+10
# Industrial development                 32120                                     1.973854e+10
# Power generation/non-renewable sources 23020                                     1.512861e+10
# RESCHEDULING AND REFINANCING           60040                                     1.479750e+10

# %%
topfive=['Air transport','Rail transport','Industrial development','Power generation/non-renewable sources','RESCHEDULING AND REFINANCING']
top5 = ['21050','21030','32120','23020','60040']

# %%
maindata = aiddata.groupby(['donor','recipient','coalesced_purpose_name','coalesced_purpose_code'],as_index=False)['commitment_amount_usd_constant'].sum()
maindata.columns=['donor','recipient','purpose','code','amount']

# %%
p1 = maindata[maindata.purpose.isin(topfive)]
p1.head()
# Out:
#          donor     recipient                                 purpose   code  \
# 152  Australia         India                  Industrial development  32120
# 172  Australia         India  Power generation/non-renewable sources  23020
# 177  Australia         India                          Rail transport  21030
# 277  Australia  South Africa                  Industrial development  32120
# 336  Australia      Thailand                           Air transport  21050
#
#          amount
# 152  24434534.0
# 172   3917484.0
# 177   2671116.0
# 277     91287.0
# 336     75135.0

# %%
data_f = p1[p1['donor'].isin(donorlist)]
data_f = data_f[data_f['recipient'].isin(receplist)]
data_f = data_f.sort_values(by = ["amount"], ascending=False)
data_f
# Out:
#                donor     recipient                                 purpose  \
# 5414         Germany        Poland            RESCHEDULING AND REFINANCING
# 7541           Japan         India                          Rail transport
# 13752  United States         Korea                           Air transport
# 8017           Japan      Thailand                          Rail transport
# 7534           Japan         India  Power generation/non-renewable sources
# 13143  United States        Brazil                           Air transport
# 14012  United States  Saudi Arabia                           Air transport
# 7924           Japan      Thailand                           Air transport
# 7515           Japan         India                  Industrial development
# 13612  United States         India                           Air transport
# 13197  United States        Brazil                  Industrial development
# ...

# %%
data_f.to_csv("maindata.csv")

# %%
donors = aiddata.groupby(['donor'],as_index=False)['commitment_amount_usd_constant'].sum()
donors = donors.sort_values(by=["commitment_amount_usd_constant"], ascending=False)
donor_f = donors.head(20)
donor_f
# Out:
#              donor  commitment_amount_usd_constant
# 41   United States                    1.161763e+11
# 19           Japan                    1.141823e+11
# 13         Germany                    4.721844e+10
# 40  United Kingdom                    2.369054e+10
# 12          France                    1.545646e+10
# 25     Netherlands                    8.939647e+09
# 4           Canada                    7.466338e+09
# 35          Sweden                    6.364046e+09
# 27          Norway                    4.416814e+09
# 18           Italy                    3.835656e+09
# 9          Denmark                    2.952416e+09
# 36     Switzerland                    2.844088e+09
# 0        Australia                    2.446616e+09
# 2          Belgium                    2.144445e+09
# 34           Spain                    2.014696e+09
# 31    Saudi Arabia                    1.698411e+09
# 21          Kuwait                    1.369078e+09
# ...

# %%
donorlist = donor_f['donor'].tolist()
donorlist
# Out:
# ['United States',
#  'Japan',
#  'Germany',
#  'United Kingdom',
#  'France',
#  'Netherlands',
#  'Canada',
#  'Sweden',
#  'Norway',
#  'Italy',
#  'Denmark',
#  'Switzerland',
#  'Australia',
#  'Belgium',
#  'Spain',
#  'Saudi Arabia',
#  'Kuwait',
#  'Korea',
#  'Austria',
#  'Finland']

# %%
donor_f.to_csv("donors2.csv")

# %%
recipients = aiddata.groupby(['recipient'],as_index=False)['commitment_amount_usd_constant'].sum()
recipients = recipients.sort_values(by=["commitment_amount_usd_constant"], ascending=False)
recep_f = recipients.head(10)
recep_f
# Out:
#        recipient  commitment_amount_usd_constant
# 17         India                    1.339805e+11
# 41      Thailand                    4.904132e+10
# 3         Brazil                    3.660726e+10
# 6       Colombia                    2.553054e+10
# 21         Korea                    2.529432e+10
# 29        Poland                    2.451723e+10
# 36  South Africa                    1.865556e+10
# 22        Kuwait                    7.771540e+09
# 5          Chile                    7.334129e+09
# 33  Saudi Arabia                    4.877749e+09

# %%
receplist = recep_f['recipient'].tolist()
receplist
# Out:
# ['India',
#  'Thailand',
#  'Brazil',
#  'Colombia',
#  'Korea',
#  'Poland',
#  'South Africa',
#  'Kuwait',
#  'Chile',
#  'Saudi Arabia']

# %%
recep_f.to_csv("recipients2.csv")
