# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/Bayernlad/Downloads/aiddata-countries-only.csv")

# %%
pd.read_csv("/Users/Bayernlad/Downloads/aiddata-countries-only.csv")
# Out:
#        Unnamed: 0    aiddata_id  aiddata_2_id  year            donor  \
# 0               1  2.414478e+06           NaN  1977     Saudi Arabia
# 1               2  2.414509e+06           NaN  1977     Saudi Arabia
# 2               3  2.414635e+06           NaN  1983     Saudi Arabia
# 3               4  2.414665e+06           NaN  1984     Saudi Arabia
# 4               5  2.414667e+06           NaN  1984     Saudi Arabia
# 5               6  2.414684e+06           NaN  1985     Saudi Arabia
# 6               7  2.414760e+06           NaN  1987     Saudi Arabia
# 7               8  2.414840e+06           NaN  1993           Kuwait
# 8               9  2.415076e+06           NaN  1996           Kuwait
# 9              10  2.415206e+06           NaN  1998           Kuwait
# 10             11  2.426999e+06           NaN  1978           Kuwait
# 11             12  2.427052e+06           NaN  1976           Kuwait
# 12             13  2.427058e+06           NaN  1976           Kuwait
# ...

# %%
countries=data.recipient.unique()
print(countries)
# Out:
# ['India' 'Brazil' 'Taiwan' 'Korea' 'Cyprus' 'Lithuania' 'Thailand'
#  'Slovak Republic' 'United States' 'South Africa' 'Colombia' 'France'
#  'Chile' 'Poland' 'Czech Republic' 'Romania' 'Canada' 'Australia' 'Sweden'
#  'Hungary' 'Denmark' 'Finland' 'Greece' 'Austria' 'Ireland' 'Japan'
#  'Luxembourg' 'Saudi Arabia' 'New Zealand' 'United Kingdom' 'Belgium'
#  'Norway' 'Italy' 'Portugal' 'Qatar' 'Spain' 'Kuwait' 'Liechtenstein'
#  'Latvia' 'Estonia' 'Iceland' 'Switzerland' 'Germany' 'Slovenia'
#  'United Arab Emirates']

# %%
purpose = data.groupby(["coalesced_purpose_name","coalesced_purpose_code"])["commitment_amount_usd_constant"].sum()
df = pd.DataFrame(purpose)
##purpose_F = purpose.sort_values(['commitment_amount_usd_constant'], ascending=False)

# %%
purpose_F = df.sort_values(['commitment_amount_usd_constant'], ascending=False)
purpose_F.head(10)
# Out:
#                                                                commitment_amount_usd_constant
# coalesced_purpose_name                 coalesced_purpose_code
# Air transport                          21050                                     3.981248e+10
# Rail transport                         21030                                     2.049887e+10
# Industrial development                 32120                                     1.973854e+10
# Power generation/non-renewable sources 23020                                     1.512861e+10
# RESCHEDULING AND REFINANCING           60040                                     1.479750e+10
# Import support (capital goods)         53030                                     9.964352e+09
# Social/ welfare services               16010                                     9.206729e+09
# Telecommunications                     22020                                     8.625393e+09
# ...

# %%
p = data.groupby(["recipient","coalesced_purpose_name","coalesced_purpose_code"],as_index=False)["commitment_amount_usd_constant"].sum()
p1 = pd.DataFrame(p)
p1.columns=['Country','Purpose','Code','Amount']
p1.head()
# Out:
#      Country                                    Purpose   Code        Amount
# 0  Australia                              Air transport  21050  2.414954e+09
# 1  Australia                     Industrial development  32120  8.970500e+06
# 2  Australia  Mineral/Metal prospection and exploration  32220  6.883050e+07
# 3  Australia               Radio/television/print media  22030  1.149053e+07
# 4  Australia                             Rail transport  21030  6.837255e+07

# %%
topfive = ["Air transport","Rail transport","Industrial development","Power generation/non-renewable sources","RESCHEDULING AND REFINANCING"]
p1 = p1[p1.Purpose.isin(topfive)]
p1["Country"].replace({"Korea": "South Korea", "Slovak Republic": "Slovakia"}, inplace=True)

# %%
p1.to_csv('data.csv')

# %%
countrydata = pd.read_json('/Users/Bayernlad/Desktop/InfoViz/Viz1/Q3/capital-geo.json')
countrydata=countrydata.rename(columns={'CountryName':'Country'})

# %%
result = pd.merge(p1,
                 countrydata,
                 on='Country')

# %%
result.sort_values(by=['ContinentName'], inplace=True)

# %%
result.to_csv("viz3data.csv")
