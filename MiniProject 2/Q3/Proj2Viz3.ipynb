# %%
import pandas as pd

# %%
aiddata = pd.read_csv("/Users/Bayernlad/Downloads/aiddata-countries-only.csv")

# %%
pd.read_csv("/Users/Bayernlad/Downloads/aiddata-countries-only.csv")
# Out:
#        Unnamed: 0    aiddata_id  aiddata_2_id  year            donor  \
# 0               1  2.414478e+06           NaN  1977     Saudi Arabia
# 1               2  2.414509e+06           NaN  1977     Saudi Arabia
# 2               3  2.414635e+06           NaN  1983     Saudi Arabia
# 3               4  2.414665e+06           NaN  1984     Saudi Arabia
# 4               5  2.414667e+06           NaN  1984     Saudi Arabia
# 5               6  2.414684e+06           NaN  1985     Saudi Arabia
# 6               7  2.414760e+06           NaN  1987     Saudi Arabia
# 7               8  2.414840e+06           NaN  1993           Kuwait
# 8               9  2.415076e+06           NaN  1996           Kuwait
# 9              10  2.415206e+06           NaN  1998           Kuwait
# 10             11  2.426999e+06           NaN  1978           Kuwait
# 11             12  2.427052e+06           NaN  1976           Kuwait
# 12             13  2.427058e+06           NaN  1976           Kuwait
# ...

# %%
d1 = aiddata.groupby(["year","recipient"],as_index=False)["commitment_amount_usd_constant"].sum()
df1 = pd.DataFrame(d1)

# %%
df1 = df1.sort_values(['year'], ascending=True)
df1.columns=['year','country','amount']
df1["country"].replace({"Korea": "South Korea", "Slovak Republic": "Slovakia"}, inplace=True)

# %%
df1.to_csv("q3data1.csv")

# %%
d2 = aiddata.groupby(["recipient"],as_index=False)["commitment_amount_usd_constant"].sum()
df2 = pd.DataFrame(d2)
df2.columns=['country','amount']
df2["country"].replace({"Korea": "South Korea", "Slovak Republic": "Slovakia"}, inplace=True)

# %%
countrydata = pd.read_json('/Users/Bayernlad/Desktop/capital.json')
countrydata=countrydata.rename(columns={'CountryName':'country'})

# %%
result = pd.merge(df2,
                 countrydata,
                 on='country')
result.head(50)
# Out:
#                  country        amount      CapitalLatitude  CapitalLongitude  \
# 0              Australia  2.572618e+09  -35.266666666666666        149.133333
# 1                Austria  7.702674e+08                 48.2         16.366667
# 2                Belgium  1.843462e+08   50.833333333333336          4.333333
# 3                 Brazil  3.660726e+10  -15.783333333333333        -47.916667
# 4                 Canada  4.068653e+09   45.416666666666664        -75.700000
# 5                  Chile  7.334129e+09               -33.45        -70.666667
# 6               Colombia  2.553054e+10                  4.6        -74.083333
# 7                 Cyprus  9.681549e+08   35.166666666666664         33.366667
# 8         Czech Republic  2.141913e+09   50.083333333333336         14.466667
# 9                Denmark  1.663106e+08   55.666666666666664         12.583333
# 10               Estonia  2.513495e+08    59.43333333333333         24.716667
# ...

# %%
result.sort_values(by=['ContinentName'], inplace=True)
result.to_csv("countrydataViz3.csv")

# %%
d3 = aiddata.groupby(["year"],as_index=False)["commitment_amount_usd_constant"].sum()
df3 = pd.DataFrame(d3)
df3.columns=['year','amount']

# %%
df3.to_csv("years.csv")
